# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # FGSM

# %%
data = pd.read_csv('/content/FGSM.csv')

# Calculate accuracy on adversarial images
correct_predictions = data['Original Image'] == data['Prediction on Adversarial Image']
accuracy = correct_predictions.mean()

# Calculate mean prediction probability drop
probability_drop = data['Original Prediction Probability'] - data['Prediction Probability for Adversarial Image']
mean_probability_drop = probability_drop.mean()

# Calculate successful attack rate (where the prediction changed)
successful_attacks = data['Original Image'] != data['Prediction on Adversarial Image']
successful_attack_rate = successful_attacks.mean()

# Calculate confidence reduction in successful attacks
confidence_reduction = probability_drop[successful_attacks].mean()

# Global Metrics
overall_accuracy = correct_predictions.mean()
overall_mean_probability_drop = probability_drop.mean()
overall_successful_attack_rate = successful_attacks.mean()
overall_confidence_reduction = confidence_reduction

# Class-Wise Metrics Calculation
class_metrics = data.groupby('Original Image').apply(
    lambda group: pd.Series({
        'Class Accuracy': (group['Original Image'] == group['Prediction on Adversarial Image']).mean(),
        'Mean Prediction Probability Drop': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image']).mean(),
        'Successful Attack Rate': (group['Original Image'] != group['Prediction on Adversarial Image']).mean(),
        'Confidence Reduction in Successful Attacks': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image'])[group['Original Image'] != group['Prediction on Adversarial Image']].mean()
    })
)

# Ranking the classes based on vulnerability and confidence reduction
class_metrics['Vulnerability Rank'] = class_metrics['Successful Attack Rate'].rank(ascending=False)
class_metrics['Confidence Reduction Rank'] = class_metrics['Confidence Reduction in Successful Attacks'].rank(ascending=False)

# Display global metrics
print(f"Overall Accuracy on Adversarial Images: {overall_accuracy * 100:.2f}%")
print(f"Overall Mean Prediction Probability Drop: {overall_mean_probability_drop:.2f}%")
print(f"Overall Successful Attack Rate: {overall_successful_attack_rate * 100:.2f}%")
print(f"Overall Mean Confidence Reduction in Successful Attacks: {overall_confidence_reduction:.2f}%")

# Display class-wise metrics
print("\nClass-Wise Metrics:")
print(class_metrics)

# Class-wise inferences
for i, row in class_metrics.iterrows():
    print(f"\nClass {i}:")
    if row['Class Accuracy'] < 0.5:
        print(" - High effectiveness of FGSM attack; low accuracy.")
    elif row['Class Accuracy'] < 0.8:
        print(" - Moderate effectiveness of FGSM attack; accuracy is moderately reduced.")
    else:
        print(" - Low effectiveness of FGSM attack; accuracy remains relatively high.")

    if row['Successful Attack Rate'] > 0.5:
        print(" - High vulnerability to adversarial attacks.")
    elif row['Successful Attack Rate'] > 0.2:
        print(" - Moderate vulnerability to adversarial attacks.")
    else:
        print(" - Low vulnerability to adversarial attacks.")

    if row['Mean Prediction Probability Drop'] > 10:
        print(" - Significant reduction in model's confidence.")
    elif row['Mean Prediction Probability Drop'] > 5:
        print(" - Moderate reduction in model's confidence.")
    else:
        print(" - Limited impact on model's confidence.")

# Display rankings
print("\nClass Vulnerability Rankings:")
print(class_metrics[['Successful Attack Rate', 'Vulnerability Rank']].sort_values(by='Vulnerability Rank'))

print("\nClass Confidence Reduction Rankings:")
print(class_metrics[['Confidence Reduction in Successful Attacks', 'Confidence Reduction Rank']].sort_values(by='Confidence Reduction Rank'))
# Out:
# Overall Accuracy on Adversarial Images: 62.22%
# Overall Mean Prediction Probability Drop: -1.44%
# Overall Successful Attack Rate: 37.78%
# Overall Mean Confidence Reduction in Successful Attacks: -1.72%
#
# Class-Wise Metrics:
#                 Class Accuracy  Mean Prediction Probability Drop  \
# Original Image
# 0                     1.000000                          0.000000
# 1                     0.333333                          0.911111
# 2                     0.777778                          0.480000
# 3                     0.555556                         -3.252222
# 4                     0.555556                         -2.175556
# 5                     0.666667                         -1.742222
# 6                     0.555556                         -0.181111
# 7                     0.888889                         -0.018889
# 8                     0.333333                        -18.638889
# 9                     0.555556                         10.173333
#
#                 Successful Attack Rate  \
# Original Image
# 0                             0.000000
# 1                             0.666667
# 2                             0.222222
# 3                             0.444444
# 4                             0.444444
# 5                             0.333333
# 6                             0.444444
# 7                             0.111111
# 8                             0.666667
# 9                             0.444444
#
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 0                                                      NaN
# 1                                                 1.681667
# 2                                                 2.545000
# 3                                                -2.430000
# 4                                                -2.120000
# 5                                                -1.526667
# 6                                                -0.107500
# 7                                                 0.070000
# 8                                               -18.613333
# 9                                                15.290000
#
#                 Vulnerability Rank  Confidence Reduction Rank
# Original Image
# 0                             10.0                        NaN
# 1                              1.5                        3.0
# 2                              8.0                        2.0
# 3                              4.5                        8.0
# 4                              4.5                        7.0
# 5                              7.0                        6.0
# 6                              4.5                        5.0
# 7                              9.0                        4.0
# 8                              1.5                        9.0
# 9                              4.5                        1.0
#
# Class 0:
#  - Low effectiveness of FGSM attack; accuracy remains relatively high.
#  - Low vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 1:
#  - High effectiveness of FGSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 2:
#  - Moderate effectiveness of FGSM attack; accuracy is moderately reduced.
#  - Moderate vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 3:
#  - Moderate effectiveness of FGSM attack; accuracy is moderately reduced.
#  - Moderate vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 4:
#  - Moderate effectiveness of FGSM attack; accuracy is moderately reduced.
#  - Moderate vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 5:
#  - Moderate effectiveness of FGSM attack; accuracy is moderately reduced.
#  - Moderate vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 6:
#  - Moderate effectiveness of FGSM attack; accuracy is moderately reduced.
#  - Moderate vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 7:
#  - Low effectiveness of FGSM attack; accuracy remains relatively high.
#  - Low vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 8:
#  - High effectiveness of FGSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 9:
#  - Moderate effectiveness of FGSM attack; accuracy is moderately reduced.
#  - Moderate vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class Vulnerability Rankings:
#                 Successful Attack Rate  Vulnerability Rank
# Original Image
# 1                             0.666667                 1.5
# 8                             0.666667                 1.5
# 3                             0.444444                 4.5
# 4                             0.444444                 4.5
# 6                             0.444444                 4.5
# 9                             0.444444                 4.5
# 5                             0.333333                 7.0
# 2                             0.222222                 8.0
# 7                             0.111111                 9.0
# 0                             0.000000                10.0
#
# Class Confidence Reduction Rankings:
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 9                                                15.290000
# 2                                                 2.545000
# 1                                                 1.681667
# 7                                                 0.070000
# 6                                                -0.107500
# 5                                                -1.526667
# 4                                                -2.120000
# 3                                                -2.430000
# 8                                               -18.613333
# 0                                                      NaN
#
#                 Confidence Reduction Rank
# Original Image
# 9                                     1.0
# 2                                     2.0
# 1                                     3.0
# 7                                     4.0
# 6                                     5.0
# 5                                     6.0
# 4                                     7.0
# 3                                     8.0
# 8                                     9.0
# 0                                     NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'class_metrics' contains the calculated class-wise metrics and ranks.
sns.set(style="whitegrid")

# 1. Bar Plot for Class Accuracy with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Class Accuracy', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Class Accuracy After FGSM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 2. Bar Plot for Mean Prediction Probability Drop with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Mean Prediction Probability Drop', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Mean Prediction Probability Drop After FGSM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Mean Prediction Probability Drop')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 3. Bar Plot for Successful Attack Rate with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Successful Attack Rate', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Successful Attack Rate by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Successful Attack Rate')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 4. Bar Plot for Confidence Reduction in Successful Attacks with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Confidence Reduction in Successful Attacks', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Confidence Reduction in Successful Attacks by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Confidence Reduction')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 5. Scatter Plot for Vulnerability vs Confidence Reduction Rankings with Annotations
plt.figure(figsize=(7,5))
ax = sns.scatterplot(x='Vulnerability Rank', y='Confidence Reduction Rank', data=class_metrics, hue=class_metrics.index,
                     palette='Set2', s=100)

# Labeling each point with the class
for i in range(class_metrics.shape[0]):
    ax.text(class_metrics['Vulnerability Rank'][i]+0.1, class_metrics['Confidence Reduction Rank'][i],
            class_metrics.index[i], horizontalalignment='left', size='medium', color='black', weight='semibold')

plt.title('Vulnerability vs Confidence Reduction Rankings by Class')
plt.xlabel('Vulnerability Rank')
plt.ylabel('Confidence Reduction Rank')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust position to the right
plt.tight_layout()  # Adjust layout to accommodate legend
plt.show()

# 6. Heatmap for Class-Wise Metrics
plt.figure(figsize=(12,8))
heatmap_data = class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                              'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']]
ax = sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, cbar_kws={'label': 'Metric Value'})
plt.title('Class-Wise Metrics After FGSM Attack')
plt.xlabel('Metrics')
plt.ylabel('Original Image Class')
plt.tight_layout()
plt.show()

# 7. Optional: Pie Chart for Overall Successful Attack Rate
plt.figure(figsize=(7,5))
success_rate = [overall_successful_attack_rate, 1 - overall_successful_attack_rate]
labels = ['Successful Attacks', 'Unsuccessful Attacks']
colors = ['#ff9999','#66b3ff']
plt.pie(success_rate, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Overall Successful Attack Rate')
plt.tight_layout()
plt.show()

# 8. Boxplot for Metric Distribution Across Classes
plt.figure(figsize=(7,5))
ax = sns.boxplot(data=class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                                     'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']], palette='Set3')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.title('Distribution of Metrics Across Classes')
plt.xlabel('Metrics')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-70-dba7f1a448f8>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')
# <ipython-input-70-dba7f1a448f8>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')
# <ipython-input-70-dba7f1a448f8>:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')
# <ipython-input-70-dba7f1a448f8>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# <ipython-input-70-dba7f1a448f8>:119: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")

# %% [markdown]
# # BIM

# %%
data = pd.read_csv('/content/BIM.csv')

# Calculate accuracy on adversarial images
correct_predictions = data['Original Image'] == data['Prediction on Adversarial Image']
accuracy = correct_predictions.mean()

# Calculate mean prediction probability drop
probability_drop = data['Original Prediction Probability'] - data['Prediction Probability for Adversarial Image']
mean_probability_drop = probability_drop.mean()

# Calculate successful attack rate (where the prediction changed)
successful_attacks = data['Original Image'] != data['Prediction on Adversarial Image']
successful_attack_rate = successful_attacks.mean()

# Calculate confidence reduction in successful attacks
confidence_reduction = probability_drop[successful_attacks].mean()

# Global Metrics
overall_accuracy = correct_predictions.mean()
overall_mean_probability_drop = probability_drop.mean()
overall_successful_attack_rate = successful_attacks.mean()
overall_confidence_reduction = confidence_reduction

# Class-Wise Metrics Calculation
class_metrics = data.groupby('Original Image').apply(
    lambda group: pd.Series({
        'Class Accuracy': (group['Original Image'] == group['Prediction on Adversarial Image']).mean(),
        'Mean Prediction Probability Drop': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image']).mean(),
        'Successful Attack Rate': (group['Original Image'] != group['Prediction on Adversarial Image']).mean(),
        'Confidence Reduction in Successful Attacks': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image'])[group['Original Image'] != group['Prediction on Adversarial Image']].mean()
    })
)

# Ranking the classes based on vulnerability and confidence reduction
class_metrics['Vulnerability Rank'] = class_metrics['Successful Attack Rate'].rank(ascending=False)
class_metrics['Confidence Reduction Rank'] = class_metrics['Confidence Reduction in Successful Attacks'].rank(ascending=False)

# Display global metrics
print(f"Overall Accuracy on Adversarial Images: {overall_accuracy * 100:.2f}%")
print(f"Overall Mean Prediction Probability Drop: {overall_mean_probability_drop:.2f}%")
print(f"Overall Successful Attack Rate: {overall_successful_attack_rate * 100:.2f}%")
print(f"Overall Mean Confidence Reduction in Successful Attacks: {overall_confidence_reduction:.2f}%")

# Display class-wise metrics
print("\nClass-Wise Metrics:")
print(class_metrics)

# Class-wise inferences
for i, row in class_metrics.iterrows():
    print(f"\nClass {i}:")
    if row['Class Accuracy'] < 0.5:
        print(" - High effectiveness of BIM attack; low accuracy.")
    elif row['Class Accuracy'] < 0.8:
        print(" - Moderate effectiveness of BIM attack; accuracy is moderately reduced.")
    else:
        print(" - Low effectiveness of BIM attack; accuracy remains relatively high.")

    if row['Successful Attack Rate'] > 0.5:
        print(" - High vulnerability to adversarial attacks.")
    elif row['Successful Attack Rate'] > 0.2:
        print(" - Moderate vulnerability to adversarial attacks.")
    else:
        print(" - Low vulnerability to adversarial attacks.")

    if row['Mean Prediction Probability Drop'] > 10:
        print(" - Significant reduction in model's confidence.")
    elif row['Mean Prediction Probability Drop'] > 5:
        print(" - Moderate reduction in model's confidence.")
    else:
        print(" - Limited impact on model's confidence.")

# Display rankings
print("\nClass Vulnerability Rankings:")
print(class_metrics[['Successful Attack Rate', 'Vulnerability Rank']].sort_values(by='Vulnerability Rank'))

print("\nClass Confidence Reduction Rankings:")
print(class_metrics[['Confidence Reduction in Successful Attacks', 'Confidence Reduction Rank']].sort_values(by='Confidence Reduction Rank'))
# Out:
# Overall Accuracy on Adversarial Images: 6.67%
# Overall Mean Prediction Probability Drop: 12.35%
# Overall Successful Attack Rate: 93.33%
# Overall Mean Confidence Reduction in Successful Attacks: 11.60%
#
# Class-Wise Metrics:
#                 Class Accuracy  Mean Prediction Probability Drop  \
# Original Image
# 0                     0.444444                         14.291111
# 1                     0.000000                         16.678889
# 2                     0.222222                         16.972222
# 3                     0.000000                         11.642222
# 4                     0.000000                         20.393333
# 5                     0.000000                         12.445556
# 6                     0.000000                         24.160000
# 7                     0.000000                         10.810000
# 8                     0.000000                        -12.067778
# 9                     0.000000                          8.174444
#
#                 Successful Attack Rate  \
# Original Image
# 0                             0.555556
# 1                             1.000000
# 2                             0.777778
# 3                             1.000000
# 4                             1.000000
# 5                             1.000000
# 6                             1.000000
# 7                             1.000000
# 8                             1.000000
# 9                             1.000000
#
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 0                                                14.366000
# 1                                                16.678889
# 2                                                10.348571
# 3                                                11.642222
# 4                                                20.393333
# 5                                                12.445556
# 6                                                24.160000
# 7                                                10.810000
# 8                                               -12.067778
# 9                                                 8.174444
#
#                 Vulnerability Rank  Confidence Reduction Rank
# Original Image
# 0                             10.0                        4.0
# 1                              4.5                        3.0
# 2                              9.0                        8.0
# 3                              4.5                        6.0
# 4                              4.5                        2.0
# 5                              4.5                        5.0
# 6                              4.5                        1.0
# 7                              4.5                        7.0
# 8                              4.5                       10.0
# 9                              4.5                        9.0
#
# Class 0:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 1:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 2:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 3:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 4:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 5:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 6:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 7:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 8:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 9:
#  - High effectiveness of BIM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Moderate reduction in model's confidence.
#
# Class Vulnerability Rankings:
#                 Successful Attack Rate  Vulnerability Rank
# Original Image
# 1                             1.000000                 4.5
# 3                             1.000000                 4.5
# 4                             1.000000                 4.5
# 5                             1.000000                 4.5
# 6                             1.000000                 4.5
# 7                             1.000000                 4.5
# 8                             1.000000                 4.5
# 9                             1.000000                 4.5
# 2                             0.777778                 9.0
# 0                             0.555556                10.0
#
# Class Confidence Reduction Rankings:
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 6                                                24.160000
# 4                                                20.393333
# 1                                                16.678889
# 0                                                14.366000
# 5                                                12.445556
# 3                                                11.642222
# 7                                                10.810000
# 2                                                10.348571
# 9                                                 8.174444
# 8                                               -12.067778
#
#                 Confidence Reduction Rank
# Original Image
# 6                                     1.0
# 4                                     2.0
# 1                                     3.0
# 0                                     4.0
# 5                                     5.0
# 3                                     6.0
# 7                                     7.0
# 2                                     8.0
# 9                                     9.0
# 8                                    10.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'class_metrics' contains the calculated class-wise metrics and ranks.
sns.set(style="whitegrid")

# 1. Bar Plot for Class Accuracy with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Class Accuracy', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Class Accuracy After BIM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 2. Bar Plot for Mean Prediction Probability Drop with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Mean Prediction Probability Drop', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Mean Prediction Probability Drop After BIM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Mean Prediction Probability Drop')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 3. Bar Plot for Successful Attack Rate with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Successful Attack Rate', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Successful Attack Rate by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Successful Attack Rate')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 4. Bar Plot for Confidence Reduction in Successful Attacks with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Confidence Reduction in Successful Attacks', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Confidence Reduction in Successful Attacks by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Confidence Reduction')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 5. Scatter Plot for Vulnerability vs Confidence Reduction Rankings with Annotations
plt.figure(figsize=(7,5))
ax = sns.scatterplot(x='Vulnerability Rank', y='Confidence Reduction Rank', data=class_metrics, hue=class_metrics.index,
                     palette='Set2', s=100)

# Labeling each point with the class
for i in range(class_metrics.shape[0]):
    ax.text(class_metrics['Vulnerability Rank'][i]+0.1, class_metrics['Confidence Reduction Rank'][i],
            class_metrics.index[i], horizontalalignment='left', size='medium', color='black', weight='semibold')

plt.title('Vulnerability vs Confidence Reduction Rankings by Class')
plt.xlabel('Vulnerability Rank')
plt.ylabel('Confidence Reduction Rank')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust position to the right
plt.tight_layout()  # Adjust layout to accommodate legend
plt.show()

# 6. Heatmap for Class-Wise Metrics
plt.figure(figsize=(12,8))
heatmap_data = class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                              'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']]
ax = sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, cbar_kws={'label': 'Metric Value'})
plt.title('Class-Wise Metrics After BIM Attack')
plt.xlabel('Metrics')
plt.ylabel('Original Image Class')
plt.tight_layout()
plt.show()

# 7. Optional: Pie Chart for Overall Successful Attack Rate
plt.figure(figsize=(7,5))
success_rate = [overall_successful_attack_rate, 1 - overall_successful_attack_rate]
labels = ['Successful Attacks', 'Unsuccessful Attacks']
colors = ['#ff9999','#66b3ff']
plt.pie(success_rate, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Overall Successful Attack Rate')
plt.tight_layout()
plt.show()

# 8. Boxplot for Metric Distribution Across Classes
plt.figure(figsize=(7,5))
ax = sns.boxplot(data=class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                                     'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']], palette='Set3')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.title('Distribution of Metrics Across Classes')
plt.xlabel('Metrics')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-72-aad78e26b940>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')
# <ipython-input-72-aad78e26b940>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')
# <ipython-input-72-aad78e26b940>:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')
# <ipython-input-72-aad78e26b940>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')
# <ipython-input-72-aad78e26b940>:119: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")

# %% [markdown]
# # JBSM

# %%
data = pd.read_csv('/content/JBSM.csv')

# Calculate accuracy on adversarial images
correct_predictions = data['Original Image'] == data['Prediction on Adversarial Image']
accuracy = correct_predictions.mean()

# Calculate mean prediction probability drop
probability_drop = data['Original Prediction Probability'] - data['Prediction Probability for Adversarial Image']
mean_probability_drop = probability_drop.mean()

# Calculate successful attack rate (where the prediction changed)
successful_attacks = data['Original Image'] != data['Prediction on Adversarial Image']
successful_attack_rate = successful_attacks.mean()

# Calculate confidence reduction in successful attacks
confidence_reduction = probability_drop[successful_attacks].mean()

# Global Metrics
overall_accuracy = correct_predictions.mean()
overall_mean_probability_drop = probability_drop.mean()
overall_successful_attack_rate = successful_attacks.mean()
overall_confidence_reduction = confidence_reduction

# Class-Wise Metrics Calculation
class_metrics = data.groupby('Original Image').apply(
    lambda group: pd.Series({
        'Class Accuracy': (group['Original Image'] == group['Prediction on Adversarial Image']).mean(),
        'Mean Prediction Probability Drop': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image']).mean(),
        'Successful Attack Rate': (group['Original Image'] != group['Prediction on Adversarial Image']).mean(),
        'Confidence Reduction in Successful Attacks': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image'])[group['Original Image'] != group['Prediction on Adversarial Image']].mean()
    })
)

# Ranking the classes based on vulnerability and confidence reduction
class_metrics['Vulnerability Rank'] = class_metrics['Successful Attack Rate'].rank(ascending=False)
class_metrics['Confidence Reduction Rank'] = class_metrics['Confidence Reduction in Successful Attacks'].rank(ascending=False)

# Display global metrics
print(f"Overall Accuracy on Adversarial Images: {overall_accuracy * 100:.2f}%")
print(f"Overall Mean Prediction Probability Drop: {overall_mean_probability_drop:.2f}%")
print(f"Overall Successful Attack Rate: {overall_successful_attack_rate * 100:.2f}%")
print(f"Overall Mean Confidence Reduction in Successful Attacks: {overall_confidence_reduction:.2f}%")

# Display class-wise metrics
print("\nClass-Wise Metrics:")
print(class_metrics)

# Class-wise inferences
for i, row in class_metrics.iterrows():
    print(f"\nClass {i}:")
    if row['Class Accuracy'] < 0.5:
        print(" - High effectiveness of JBSM attack; low accuracy.")
    elif row['Class Accuracy'] < 0.8:
        print(" - Moderate effectiveness of JBSM attack; accuracy is moderately reduced.")
    else:
        print(" - Low effectiveness of JBSM attack; accuracy remains relatively high.")

    if row['Successful Attack Rate'] > 0.5:
        print(" - High vulnerability to adversarial attacks.")
    elif row['Successful Attack Rate'] > 0.2:
        print(" - Moderate vulnerability to adversarial attacks.")
    else:
        print(" - Low vulnerability to adversarial attacks.")

    if row['Mean Prediction Probability Drop'] > 10:
        print(" - Significant reduction in model's confidence.")
    elif row['Mean Prediction Probability Drop'] > 5:
        print(" - Moderate reduction in model's confidence.")
    else:
        print(" - Limited impact on model's confidence.")

# Display rankings
print("\nClass Vulnerability Rankings:")
print(class_metrics[['Successful Attack Rate', 'Vulnerability Rank']].sort_values(by='Vulnerability Rank'))

print("\nClass Confidence Reduction Rankings:")
print(class_metrics[['Confidence Reduction in Successful Attacks', 'Confidence Reduction Rank']].sort_values(by='Confidence Reduction Rank'))
# Out:
# Overall Accuracy on Adversarial Images: 4.44%
# Overall Mean Prediction Probability Drop: 7.26%
# Overall Successful Attack Rate: 95.56%
# Overall Mean Confidence Reduction in Successful Attacks: 5.95%
#
# Class-Wise Metrics:
#                 Class Accuracy  Mean Prediction Probability Drop  \
# Original Image
# 0                     0.111111                          7.567778
# 1                     0.000000                          0.371111
# 2                     0.000000                         22.124444
# 3                     0.222222                         17.597778
# 4                     0.000000                          0.695556
# 5                     0.000000                         -0.034444
# 6                     0.111111                          8.048889
# 7                     0.000000                         19.674444
# 8                     0.000000                         -7.468889
# 9                     0.000000                          4.026667
#
#                 Successful Attack Rate  \
# Original Image
# 0                             0.888889
# 1                             1.000000
# 2                             1.000000
# 3                             0.777778
# 4                             1.000000
# 5                             1.000000
# 6                             0.888889
# 7                             1.000000
# 8                             1.000000
# 9                             1.000000
#
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 0                                                 2.753750
# 1                                                 0.371111
# 2                                                22.124444
# 3                                                 8.915714
# 4                                                 0.695556
# 5                                                -0.034444
# 6                                                 9.085000
# 7                                                19.674444
# 8                                                -7.468889
# 9                                                 4.026667
#
#                 Vulnerability Rank  Confidence Reduction Rank
# Original Image
# 0                              8.5                        6.0
# 1                              4.0                        8.0
# 2                              4.0                        1.0
# 3                             10.0                        4.0
# 4                              4.0                        7.0
# 5                              4.0                        9.0
# 6                              8.5                        3.0
# 7                              4.0                        2.0
# 8                              4.0                       10.0
# 9                              4.0                        5.0
#
# Class 0:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Moderate reduction in model's confidence.
#
# Class 1:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 2:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 3:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 4:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 5:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 6:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Moderate reduction in model's confidence.
#
# Class 7:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 8:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class 9:
#  - High effectiveness of JBSM attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Limited impact on model's confidence.
#
# Class Vulnerability Rankings:
#                 Successful Attack Rate  Vulnerability Rank
# Original Image
# 1                             1.000000                 4.0
# 2                             1.000000                 4.0
# 4                             1.000000                 4.0
# 5                             1.000000                 4.0
# 7                             1.000000                 4.0
# 8                             1.000000                 4.0
# 9                             1.000000                 4.0
# 0                             0.888889                 8.5
# 6                             0.888889                 8.5
# 3                             0.777778                10.0
#
# Class Confidence Reduction Rankings:
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 2                                                22.124444
# 7                                                19.674444
# 6                                                 9.085000
# 3                                                 8.915714
# 9                                                 4.026667
# 0                                                 2.753750
# 4                                                 0.695556
# 1                                                 0.371111
# 5                                                -0.034444
# 8                                                -7.468889
#
#                 Confidence Reduction Rank
# Original Image
# 2                                     1.0
# 7                                     2.0
# 6                                     3.0
# 3                                     4.0
# 9                                     5.0
# 0                                     6.0
# 4                                     7.0
# 1                                     8.0
# 5                                     9.0
# 8                                    10.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'class_metrics' contains the calculated class-wise metrics and ranks.
sns.set(style="whitegrid")

# 1. Bar Plot for Class Accuracy with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Class Accuracy', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Class Accuracy After JBSM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 2. Bar Plot for Mean Prediction Probability Drop with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Mean Prediction Probability Drop', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Mean Prediction Probability Drop After JBSM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Mean Prediction Probability Drop')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 3. Bar Plot for Successful Attack Rate with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Successful Attack Rate', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Successful Attack Rate by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Successful Attack Rate')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 4. Bar Plot for Confidence Reduction in Successful Attacks with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Confidence Reduction in Successful Attacks', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Confidence Reduction in Successful Attacks by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Confidence Reduction')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 5. Scatter Plot for Vulnerability vs Confidence Reduction Rankings with Annotations
plt.figure(figsize=(7,5))
ax = sns.scatterplot(x='Vulnerability Rank', y='Confidence Reduction Rank', data=class_metrics, hue=class_metrics.index,
                     palette='Set2', s=100)

# Labeling each point with the class
for i in range(class_metrics.shape[0]):
    ax.text(class_metrics['Vulnerability Rank'][i]+0.1, class_metrics['Confidence Reduction Rank'][i],
            class_metrics.index[i], horizontalalignment='left', size='medium', color='black', weight='semibold')

plt.title('Vulnerability vs Confidence Reduction Rankings by Class')
plt.xlabel('Vulnerability Rank')
plt.ylabel('Confidence Reduction Rank')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust position to the right
plt.tight_layout()  # Adjust layout to accommodate legend
plt.show()

# 6. Heatmap for Class-Wise Metrics
plt.figure(figsize=(12,8))
heatmap_data = class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                              'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']]
ax = sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, cbar_kws={'label': 'Metric Value'})
plt.title('Class-Wise Metrics After JBSM Attack')
plt.xlabel('Metrics')
plt.ylabel('Original Image Class')
plt.tight_layout()
plt.show()

# 7. Optional: Pie Chart for Overall Successful Attack Rate
plt.figure(figsize=(7,5))
success_rate = [overall_successful_attack_rate, 1 - overall_successful_attack_rate]
labels = ['Successful Attacks', 'Unsuccessful Attacks']
colors = ['#ff9999','#66b3ff']
plt.pie(success_rate, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Overall Successful Attack Rate')
plt.tight_layout()
plt.show()

# 8. Boxplot for Metric Distribution Across Classes
plt.figure(figsize=(7,5))
ax = sns.boxplot(data=class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                                     'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']], palette='Set3')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.title('Distribution of Metrics Across Classes')
plt.xlabel('Metrics')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-74-617ae8571d92>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')
# <ipython-input-74-617ae8571d92>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')
# <ipython-input-74-617ae8571d92>:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')
# <ipython-input-74-617ae8571d92>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')
# <ipython-input-74-617ae8571d92>:119: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")

# %% [markdown]
# # CW

# %%
data = pd.read_csv('/content/CW.csv')

# Calculate accuracy on adversarial images
correct_predictions = data['Original Image'] == data['Prediction on Adversarial Image']
accuracy = correct_predictions.mean()

# Calculate mean prediction probability drop
probability_drop = data['Original Prediction Probability'] - data['Prediction Probability for Adversarial Image']
mean_probability_drop = probability_drop.mean()

# Calculate successful attack rate (where the prediction changed)
successful_attacks = data['Original Image'] != data['Prediction on Adversarial Image']
successful_attack_rate = successful_attacks.mean()

# Calculate confidence reduction in successful attacks
confidence_reduction = probability_drop[successful_attacks].mean()

# Global Metrics
overall_accuracy = correct_predictions.mean()
overall_mean_probability_drop = probability_drop.mean()
overall_successful_attack_rate = successful_attacks.mean()
overall_confidence_reduction = confidence_reduction

# Class-Wise Metrics Calculation
class_metrics = data.groupby('Original Image').apply(
    lambda group: pd.Series({
        'Class Accuracy': (group['Original Image'] == group['Prediction on Adversarial Image']).mean(),
        'Mean Prediction Probability Drop': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image']).mean(),
        'Successful Attack Rate': (group['Original Image'] != group['Prediction on Adversarial Image']).mean(),
        'Confidence Reduction in Successful Attacks': (group['Original Prediction Probability'] - group['Prediction Probability for Adversarial Image'])[group['Original Image'] != group['Prediction on Adversarial Image']].mean()
    })
)

# Ranking the classes based on vulnerability and confidence reduction
class_metrics['Vulnerability Rank'] = class_metrics['Successful Attack Rate'].rank(ascending=False)
class_metrics['Confidence Reduction Rank'] = class_metrics['Confidence Reduction in Successful Attacks'].rank(ascending=False)

# Display global metrics
print(f"Overall Accuracy on Adversarial Images: {overall_accuracy * 100:.2f}%")
print(f"Overall Mean Prediction Probability Drop: {overall_mean_probability_drop:.2f}%")
print(f"Overall Successful Attack Rate: {overall_successful_attack_rate * 100:.2f}%")
print(f"Overall Mean Confidence Reduction in Successful Attacks: {overall_confidence_reduction:.2f}%")

# Display class-wise metrics
print("\nClass-Wise Metrics:")
print(class_metrics)

# Class-wise inferences
for i, row in class_metrics.iterrows():
    print(f"\nClass {i}:")
    if row['Class Accuracy'] < 0.5:
        print(" - High effectiveness of CW attack; low accuracy.")
    elif row['Class Accuracy'] < 0.8:
        print(" - Moderate effectiveness of CW attack; accuracy is moderately reduced.")
    else:
        print(" - Low effectiveness of CW attack; accuracy remains relatively high.")

    if row['Successful Attack Rate'] > 0.5:
        print(" - High vulnerability to adversarial attacks.")
    elif row['Successful Attack Rate'] > 0.2:
        print(" - Moderate vulnerability to adversarial attacks.")
    else:
        print(" - Low vulnerability to adversarial attacks.")

    if row['Mean Prediction Probability Drop'] > 10:
        print(" - Significant reduction in model's confidence.")
    elif row['Mean Prediction Probability Drop'] > 5:
        print(" - Moderate reduction in model's confidence.")
    else:
        print(" - Limited impact on model's confidence.")

# Display rankings
print("\nClass Vulnerability Rankings:")
print(class_metrics[['Successful Attack Rate', 'Vulnerability Rank']].sort_values(by='Vulnerability Rank'))

print("\nClass Confidence Reduction Rankings:")
print(class_metrics[['Confidence Reduction in Successful Attacks', 'Confidence Reduction Rank']].sort_values(by='Confidence Reduction Rank'))
# Out:
# Overall Accuracy on Adversarial Images: 0.00%
# Overall Mean Prediction Probability Drop: 39.68%
# Overall Successful Attack Rate: 100.00%
# Overall Mean Confidence Reduction in Successful Attacks: 39.68%
#
# Class-Wise Metrics:
#                 Class Accuracy  Mean Prediction Probability Drop  \
# Original Image
# 0                          0.0                         36.257778
# 1                          0.0                         44.171111
# 2                          0.0                         44.442222
# 3                          0.0                         38.183333
# 4                          0.0                         43.320000
# 5                          0.0                         43.693333
# 6                          0.0                         38.456667
# 7                          0.0                         41.802222
# 8                          0.0                         19.466667
# 9                          0.0                         46.973333
#
#                 Successful Attack Rate  \
# Original Image
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
# 5                                  1.0
# 6                                  1.0
# 7                                  1.0
# 8                                  1.0
# 9                                  1.0
#
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 0                                                36.257778
# 1                                                44.171111
# 2                                                44.442222
# 3                                                38.183333
# 4                                                43.320000
# 5                                                43.693333
# 6                                                38.456667
# 7                                                41.802222
# 8                                                19.466667
# 9                                                46.973333
#
#                 Vulnerability Rank  Confidence Reduction Rank
# Original Image
# 0                              5.5                        9.0
# 1                              5.5                        3.0
# 2                              5.5                        2.0
# 3                              5.5                        8.0
# 4                              5.5                        5.0
# 5                              5.5                        4.0
# 6                              5.5                        7.0
# 7                              5.5                        6.0
# 8                              5.5                       10.0
# 9                              5.5                        1.0
#
# Class 0:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 1:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 2:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 3:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 4:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 5:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 6:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 7:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 8:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class 9:
#  - High effectiveness of CW attack; low accuracy.
#  - High vulnerability to adversarial attacks.
#  - Significant reduction in model's confidence.
#
# Class Vulnerability Rankings:
#                 Successful Attack Rate  Vulnerability Rank
# Original Image
# 0                                  1.0                 5.5
# 1                                  1.0                 5.5
# 2                                  1.0                 5.5
# 3                                  1.0                 5.5
# 4                                  1.0                 5.5
# 5                                  1.0                 5.5
# 6                                  1.0                 5.5
# 7                                  1.0                 5.5
# 8                                  1.0                 5.5
# 9                                  1.0                 5.5
#
# Class Confidence Reduction Rankings:
#                 Confidence Reduction in Successful Attacks  \
# Original Image
# 9                                                46.973333
# 2                                                44.442222
# 1                                                44.171111
# 5                                                43.693333
# 4                                                43.320000
# 7                                                41.802222
# 6                                                38.456667
# 3                                                38.183333
# 0                                                36.257778
# 8                                                19.466667
#
#                 Confidence Reduction Rank
# Original Image
# 9                                     1.0
# 2                                     2.0
# 1                                     3.0
# 5                                     4.0
# 4                                     5.0
# 7                                     6.0
# 6                                     7.0
# 3                                     8.0
# 0                                     9.0
# 8                                    10.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'class_metrics' contains the calculated class-wise metrics and ranks.
sns.set(style="whitegrid")

# 1. Bar Plot for Class Accuracy with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Class Accuracy', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Class Accuracy After BIM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 2. Bar Plot for Mean Prediction Probability Drop with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Mean Prediction Probability Drop', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Mean Prediction Probability Drop After BIM Attack')
plt.xlabel('Original Image Class')
plt.ylabel('Mean Prediction Probability Drop')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 3. Bar Plot for Successful Attack Rate with Annotations and Ordering
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Successful Attack Rate', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Successful Attack Rate by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Successful Attack Rate')
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 4. Bar Plot for Confidence Reduction in Successful Attacks with Annotations
plt.figure(figsize=(7,5))
sorted_metrics = class_metrics.sort_values(by='Confidence Reduction in Successful Attacks', ascending=False)
ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points')

plt.title('Confidence Reduction in Successful Attacks by Class')
plt.xlabel('Original Image Class')
plt.ylabel('Confidence Reduction')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# 5. Scatter Plot for Vulnerability vs Confidence Reduction Rankings with Annotations
plt.figure(figsize=(7,5))
ax = sns.scatterplot(x='Vulnerability Rank', y='Confidence Reduction Rank', data=class_metrics, hue=class_metrics.index,
                     palette='Set2', s=100)

# Labeling each point with the class
for i in range(class_metrics.shape[0]):
    ax.text(class_metrics['Vulnerability Rank'][i]+0.1, class_metrics['Confidence Reduction Rank'][i],
            class_metrics.index[i], horizontalalignment='left', size='medium', color='black', weight='semibold')

plt.title('Vulnerability vs Confidence Reduction Rankings by Class')
plt.xlabel('Vulnerability Rank')
plt.ylabel('Confidence Reduction Rank')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust position to the right
plt.tight_layout()  # Adjust layout to accommodate legend
plt.show()

# 6. Heatmap for Class-Wise Metrics
plt.figure(figsize=(12,8))
heatmap_data = class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                              'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']]
ax = sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, cbar_kws={'label': 'Metric Value'})
plt.title('Class-Wise Metrics After BIM Attack')
plt.xlabel('Metrics')
plt.ylabel('Original Image Class')
plt.tight_layout()
plt.show()

# 7. Optional: Pie Chart for Overall Successful Attack Rate
plt.figure(figsize=(7,5))
success_rate = [overall_successful_attack_rate, 1 - overall_successful_attack_rate]
labels = ['Successful Attacks', 'Unsuccessful Attacks']
colors = ['#ff9999','#66b3ff']
plt.pie(success_rate, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Overall Successful Attack Rate')
plt.tight_layout()
plt.show()

# 8. Boxplot for Metric Distribution Across Classes
plt.figure(figsize=(7,5))
ax = sns.boxplot(data=class_metrics[['Class Accuracy', 'Mean Prediction Probability Drop',
                                     'Successful Attack Rate', 'Confidence Reduction in Successful Attacks']], palette='Set3')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.title('Distribution of Metrics Across Classes')
plt.xlabel('Metrics')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-76-aad78e26b940>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Class Accuracy', data=sorted_metrics, palette='viridis')
# <ipython-input-76-aad78e26b940>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Mean Prediction Probability Drop', data=sorted_metrics, palette='coolwarm')
# <ipython-input-76-aad78e26b940>:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Successful Attack Rate', data=sorted_metrics, palette='magma')
# <ipython-input-76-aad78e26b940>:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sorted_metrics.index, y='Confidence Reduction in Successful Attacks', data=sorted_metrics, palette='coolwarm')
# <ipython-input-76-aad78e26b940>:119: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
